# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test için bir sorgu
response = qa({"query": "Okul kartımı kaybettim, ne yapabilirim?"})
print(response)
# Out:
# /var/folders/p1/1dwyrw9j2dg5n7m_bh0p0xlh0000gn/T/ipykernel_52727/1561111604.py:10: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = qa({"query": "Okul kartımı kaybettim, ne yapabilirim?"})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 10
#       7 qa = create_qa_chain(chroma_db, llm, PROMPT)
#       9 # Test için bir sorgu
# ---> 10 response = qa({"query": "Okul kartımı kaybettim, ne yapabilirim?"})
#      11 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# ...

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.5.1
# False

# %%
import torch

# Tensor oluştur ve işlemleri CPU üzerinde yap
x = torch.tensor([1.0, 2.0, 3.0])
y = x + x
print(y)

# Cihaz türünü kontrol et
print(f"Tensor cihazı: {x.device}")
# Out:
# tensor([2., 4., 6.])
# Tensor cihazı: cpu

# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test için bir sorgu
query = "Okul kartımı kaybettim, ne yapabilirim?"
response = qa.invoke({"context": "Örnek bağlam metni", "query": query})
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       9 # Test için bir sorgu
#      10 query = "Okul kartımı kaybettim, ne yapabilirim?"
# ---> 11 response = qa.invoke({"context": "Örnek bağlam metni", "query": query})
#      12 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# ...

# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test sorgusu
context = "Örnek bağlam metni"  # Bağlam metni
query = "Okul kartımı kaybettim, ne yapabilirim?"  # Kullanıcı sorgusu

response = qa.invoke({"context": context, "query": query})  # Hem 'context' hem de 'query' sağlanıyor
print(response)

print(f"Context türü: {type(context)}, Değer: {context}")
print(f"Query türü: {type(query)}, Değer: {query}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 13
#      10 context = "Örnek bağlam metni"  # Bağlam metni
#      11 query = "Okul kartımı kaybettim, ne yapabilirim?"  # Kullanıcı sorgusu
# ---> 13 response = qa.invoke({"context": context, "query": query})  # Hem 'context' hem de 'query' sağlanıyor
#      14 print(response)
#      16 print(f"Context türü: {type(context)}, Değer: {context}")
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# ...

# %%
print(f"Context türü: {type(context)}, Değer: {context}")
print(f"Query türü: {type(query)}, Değer: {query}")
# Out:
# Context türü: <class 'str'>, Değer: Örnek bağlam metni
# Query türü: <class 'str'>, Değer: Okul kartımı kaybettim, ne yapabilirim?

# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test için sorgu
context = "Örnek bağlam metni"
query = "Okul kartımı kaybettim, ne yapabilirim?"

response = qa.invoke({"context": context, "query": query})
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 13
#      10 context = "Örnek bağlam metni"
#      11 query = "Okul kartımı kaybettim, ne yapabilirim?"
# ---> 13 response = qa.invoke({"context": context, "query": query})
#      14 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# ...

# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test için bağlam ve sorgu
context = "Öğrenci işleri hakkında genel bilgiler."  # Örnek bağlam
query = "Okul kartımı kaybettim, ne yapabilirim?"  # Kullanıcı sorgusu

response = qa.invoke({"context": context, "query": query})  # Zincire bağlam ve sorguyu gönder
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 13
#      10 context = "Öğrenci işleri hakkında genel bilgiler."  # Örnek bağlam
#      11 query = "Okul kartımı kaybettim, ne yapabilirim?"  # Kullanıcı sorgusu
# ---> 13 response = qa.invoke({"context": context, "query": query})  # Zincire bağlam ve sorguyu gönder
#      14 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
# ...

# %%
print(f"Zincirin beklediği anahtarlar: {qa.input_keys}")
# Out:
# Zincirin beklediği anahtarlar: ['query']

# %%
query = "Okul kartımı kaybettim, ne yapabilirim?"
response = qa.invoke({"query": query})  # Sadece 'query' anahtarı gönderiliyor
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 query = "Okul kartımı kaybettim, ne yapabilirim?"
# ----> 2 response = qa.invoke({"query": query})  # Sadece 'query' anahtarı gönderiliyor
#       3 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
# ...

# %%
from utils import load_chroma_db, load_llm, create_qa_chain, create_prompt_template

# Veritabanını ve modeli yükle
chroma_db = load_chroma_db()
llm = load_llm()
PROMPT = create_prompt_template()
qa = create_qa_chain(chroma_db, llm, PROMPT)

# Test için sorgu ve bağlam
query = "Okul kartımı kaybettim, ne yapabilirim?"
response = qa.invoke({"context": "Öğrenci işleri hakkında genel bilgiler.", "query": query})
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 11
#       9 # Test için sorgu ve bağlam
#      10 query = "Okul kartımı kaybettim, ne yapabilirim?"
# ---> 11 response = qa.invoke({"context": "Öğrenci işleri hakkında genel bilgiler.", "query": query})
#      12 print(response)
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/PycharmProjects/pythonProject7/.venv/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# ...

# %%
print(f"Zincirin beklediği anahtarlar: {qa.input_keys}")
# Out:
# Zincirin beklediği anahtarlar: ['query']
